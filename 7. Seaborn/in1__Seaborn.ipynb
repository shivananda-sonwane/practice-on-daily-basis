# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df1=sns.load_dataset("tips")
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x='tip', y='total_bill', data=df1)

# %%
#Hue is nothing but the differntiation between parameters on the basis of colors. 
sns.relplot(x='tip', y='total_bill', data=df1, hue='smoker')

# %%
sns.relplot(x='tip', y='total_bill', data=df1, hue='day')

# %%
#want to differentiate between smokers and non-smokers too.
sns.relplot(x='tip', y='total_bill', data=df1, hue='day', style='smoker')

# %%
sns.relplot(x='tip', y='total_bill', data=df1, hue='day', style='smoker', size='size')

# %%
df2=pd.DataFrame(np.random.randn(3000, 2), columns=['a', 'b'])
df2.drop_duplicates(inplace=True)
df2
# Out:
#              a         b
# 0     1.172922  0.730042
# 1     1.056578  1.018224
# 2    -0.477054  0.583603
# 3    -0.008475 -1.392900
# 4    -0.062665  0.262553
# ...        ...       ...
# 2995 -1.533391  1.818483
# 2996  1.374702  0.319958
# 2997  0.048562  0.661920
# 2998  0.321347 -0.863760
# 2999  0.198649  0.422898
#
# [3000 rows x 2 columns]

# %%
#line plot
sns.relplot(data=df2, x='a', y='b', kind='line', sort=True)

# %%
iris = sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.scatterplot(data=iris, x='sepal_length', y='petal_length', hue='species')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df1['day'].unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
sns.relplot(data=df1, x='day', y='total_bill', hue='sex', style='smoker')

# %%
#categorical plot
sns.catplot(data=df1, x="day", y="total_bill")

# %%
sns.catplot(data=df1, x="smoker", y="tip")

# %%
#box plot
sns.catplot(data=df1, x="day", y="tip", kind='box')

# %%
sns.catplot(data=df1, x="day", y="tip", kind='box', hue='sex')

# %%
df2 = np.random.randn(100,1)
df2[:5]
# Out:
# array([[ 0.49725123],
#        [ 2.29467278],
#        [-2.18303384],
#        [-0.09475388],
#        [-0.53624375]])

# %%
sns.displot(df2, kind='ecdf')

# %%
sns.distplot(df2) #Flexibly plot a univariate distribution of observations.
# Note: This function is deprecated and will be removed in a future version.
# Out:
# C:\Users\Suryansh Grover\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
df3 = np.random.randn(10000000,1)
df3[:5]
# Out:
# array([[ 1.66343168],
#        [-0.6122905 ],
#        [-1.47351054],
#        [ 0.74295972],
#        [-0.15755031]])

# %%
sns.displot(df3) #precise normal distribution as our size of our dataset increases.

# i.e larger the dataset following normal distribution, more pecise will be its curve.

# %%
df4=np.random.rand(10000000, 1)
sns.displot(df4) #uniform generated data between (0,1).

# %%
df1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### Jointplot:

# %%
sns.jointplot(data=df1, x='total_bill', y='tip') #scatter + histo

# %%
try:
    sns.jointplot(data=df1, x='total_bill', y='tip', kind = 'line') #line + histo
except Exception as e:
    print(e)
# Out:
# `kind` must be one of ['scatter', 'hist', 'hex', 'kde', 'reg', 'resid'], but line was passed.`

# %%
sns.jointplot(data=df1, x='total_bill', y='tip', kind = 'hist')

# %%
sns.jointplot(data=df1, x='total_bill', y='tip', kind = 'reg') #facet-line

# %%
sns.jointplot(data=df1, x='total_bill', y='tip', kind = 'resid')

# %% [markdown]
# ### kde i.e. a non-parametric way to estimate the probability density function of a random variable.

# %%
sns.jointplot(data=df1, x='total_bill', y='tip', kind = 'kde') #kde

# %%
#Scatter Matrix
sns.pairplot(iris) # equivalent of pd.plotting.scattermatrix(df)

# %%
'''
Plot data and regression model fits across a FacetGrid.
'''
sns.lmplot(data=df1, x='total_bill', y='tip') # Regressed plot even w/o using regression.

# %%
sns.regplot(data=df1, x='total_bill', y='tip')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.lmplot(data=df1, x='total_bill', y='tip', col='day') #for each day
