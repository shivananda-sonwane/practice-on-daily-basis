# %%
import pandas as pd, os

# %%
os.chdir("C:\\Users\\Suryansh Grover\\downloads")

# %%
curDir=os.getcwd()
curDir
# Out:
# 'C:\\Users\\Suryansh Grover\\downloads'

# %%
for i in os.listdir():
    if i.endswith('.csv'):
        print(i)
# Out:
# 2019_data_analyst_job.csv
# 3ttkl4aJQxubZJeGiZMbnw_d5afcaa17b574fa98ad9cb1fd33e82a8_Course-Challenge-Dataset---Scenario-2---Sheet1.csv
# annual-enterprise-survey-2020-financial-year-provisional-csv.csv
# carbon_nanotubes (clean).csv
# data_analyst_job.csv
# e5ixDBMRRCiYsQwTEeQo9w_5159c6848a6d458691bbba3c7fd6f5e7_Course-Challenge-Dataset---Scenario-1_-Pharmacy-Data---Part-1.csv
# GeneratedToken (1).csv
# GeneratedToken.csv
# jhzgyXyeT1ic4Ml8nh9Y-A_1350f2bd39cf4cc6bfdba5157c6a30f1_2019_data_analyst_job.csv
# titanic.csv
# XMissionDomains_ConfidentialInformation.csv

# %%
data = pd.read_csv("C:\\Users\\Suryansh Grover\\downloads\\2019_data_analyst_job.csv")
data
# Out:
#              ID            Date                    Job Title  \
# 0         24368    4/11/19 9:30  PHARMACEUTICAL DATA ANALYST
# 1         24369   6/25/19 13:30  PHARMACEUTICAL DATA ANALYST
# 2         24371   10/26/19 1:00  PHARMACEUTICAL DATA ANALYST
# 3         24374    3/2/19 19:30  PHARMACEUTICAL DATA ANALYST
# 4         24388    4/4/19 19:30  PHARMACEUTICAL DATA ANALYST
# ...         ...             ...                          ...
# 32591  12154531   8/19/19 23:31              QA DATA ANALYST
# 32592  12157329    3/8/19 17:50   MANUFACTURING DATA ANALYST
# 32593  12162108  10/23/19 12:05              QA DATA ANALYST
# 32594  12165032    2/14/19 1:44         DATA QUALITY ANALYST
# 32595  12168373    4/6/19 15:03         NETWORK DATA ANALYST
#
#             Job Location  Hired  Easy Apply
# 0             Dallas, TX  False       False
# 1             Austin, TX  False       False
# 2            Boulder, CO   True       False
# 3           New York, NY  False       False
# ...

# %% [markdown]
# ### Pandas internally tries to store the read_csv or any other extension into DataFrame type.

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.head() #by default first five rows
# Out:
#       ID           Date                    Job Title  Job Location  Hired  \
# 0  24368   4/11/19 9:30  PHARMACEUTICAL DATA ANALYST    Dallas, TX  False
# 1  24369  6/25/19 13:30  PHARMACEUTICAL DATA ANALYST    Austin, TX  False
# 2  24371  10/26/19 1:00  PHARMACEUTICAL DATA ANALYST   Boulder, CO   True
# 3  24374   3/2/19 19:30  PHARMACEUTICAL DATA ANALYST  New York, NY  False
# 4  24388   4/4/19 19:30  PHARMACEUTICAL DATA ANALYST   Chicago, IL  False
#
#    Easy Apply
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True

# %%
data.head(15)
# Out:
#        ID           Date                    Job Title       Job Location  \
# 0   24368   4/11/19 9:30  PHARMACEUTICAL DATA ANALYST         Dallas, TX
# 1   24369  6/25/19 13:30  PHARMACEUTICAL DATA ANALYST         Austin, TX
# 2   24371  10/26/19 1:00  PHARMACEUTICAL DATA ANALYST        Boulder, CO
# 3   24374   3/2/19 19:30  PHARMACEUTICAL DATA ANALYST       New York, NY
# 4   24388   4/4/19 19:30  PHARMACEUTICAL DATA ANALYST        Chicago, IL
# 5   24393  7/30/19 14:50  PHARMACEUTICAL DATA ANALYST     Long Beach, CA
# 6   24395   6/1/19 21:30  PHARMACEUTICAL DATA ANALYST      Cupertino, CA
# 7   24402  8/29/19 17:47  PHARMACEUTICAL DATA ANALYST     Richardson, TX
# 8   24426  10/9/19 13:00  PHARMACEUTICAL DATA ANALYST        Burbank, CA
# 9   24430   5/9/19 11:00  PHARMACEUTICAL DATA ANALYST    Santa Clara, CA
# 10  24434  4/18/19 20:15  PHARMACEUTICAL DATA ANALYST  San Francisco, CA
# 11  24444  10/16/19 9:44  PHARMACEUTICAL DATA ANALYST         Dallas, TX
# ...

# %%
data.tail(15)
# Out:
#              ID            Date                   Job Title  \
# 32581  12121853     2/1/19 0:18             QA DATA ANALYST
# 32582  12124900   9/14/19 20:30              DATA SCIENTIST
# 32583  12130000    4/5/19 22:00              DATA SCIENTIST
# 32584  12130639    7/27/19 6:10  MANUFACTURING DATA ANALYST
# 32585  12139443     4/6/19 9:00             QA DATA ANALYST
# 32586  12140566    6/28/19 3:30              DATA SCIENTIST
# 32587  12142571     9/9/19 2:00             QA DATA ANALYST
# 32588  12144517   12/19/19 9:00  MANUFACTURING DATA ANALYST
# 32589  12147071   10/6/19 11:00      ECOMMERCE DATA ANALYST
# 32590  12149343   10/4/19 16:30             QA DATA ANALYST
# 32591  12154531   8/19/19 23:31             QA DATA ANALYST
# 32592  12157329    3/8/19 17:50  MANUFACTURING DATA ANALYST
# 32593  12162108  10/23/19 12:05             QA DATA ANALYST
# 32594  12165032    2/14/19 1:44        DATA QUALITY ANALYST
# 32595  12168373    4/6/19 15:03        NETWORK DATA ANALYST
#
# ...

# %%
t_i = 0 #table_index
for i in os.listdir():
    if i.endswith('.csv'):
        print(f"Table {t_i}: {i}")
        print(pd.read_csv(curDir+'\\'+i))
        t_i+=1
# Out:
# Table 0: 2019_data_analyst_job.csv
#              ID            Date                    Job Title  \
# 0         24368    4/11/19 9:30  PHARMACEUTICAL DATA ANALYST
# 1         24369   6/25/19 13:30  PHARMACEUTICAL DATA ANALYST
# 2         24371   10/26/19 1:00  PHARMACEUTICAL DATA ANALYST
# 3         24374    3/2/19 19:30  PHARMACEUTICAL DATA ANALYST
# 4         24388    4/4/19 19:30  PHARMACEUTICAL DATA ANALYST
# ...         ...             ...                          ...
# 32591  12154531   8/19/19 23:31              QA DATA ANALYST
# 32592  12157329    3/8/19 17:50   MANUFACTURING DATA ANALYST
# 32593  12162108  10/23/19 12:05              QA DATA ANALYST
# 32594  12165032    2/14/19 1:44         DATA QUALITY ANALYST
# 32595  12168373    4/6/19 15:03         NETWORK DATA ANALYST
#
#             Job Location  Hired  Easy Apply
# 0             Dallas, TX  False       False
# 1             Austin, TX  False       False
# 2            Boulder, CO   True       False
# ...

# %%
data.to_csv("data_analyst_job.csv")

# %%
pd.read_csv("data_analyst_job.csv") #lil bit messy format, and we don't want that.
# Out:
#        Unnamed: 0        ID            Date                    Job Title  \
# 0               0     24368    4/11/19 9:30  PHARMACEUTICAL DATA ANALYST
# 1               1     24369   6/25/19 13:30  PHARMACEUTICAL DATA ANALYST
# 2               2     24371   10/26/19 1:00  PHARMACEUTICAL DATA ANALYST
# 3               3     24374    3/2/19 19:30  PHARMACEUTICAL DATA ANALYST
# 4               4     24388    4/4/19 19:30  PHARMACEUTICAL DATA ANALYST
# ...           ...       ...             ...                          ...
# 32591       32591  12154531   8/19/19 23:31              QA DATA ANALYST
# 32592       32592  12157329    3/8/19 17:50   MANUFACTURING DATA ANALYST
# 32593       32593  12162108  10/23/19 12:05              QA DATA ANALYST
# 32594       32594  12165032    2/14/19 1:44         DATA QUALITY ANALYST
# 32595       32595  12168373    4/6/19 15:03         NETWORK DATA ANALYST
#
#             Job Location  Hired  Easy Apply
# 0             Dallas, TX  False       False
# ...

# %% [markdown]
# ### Note: For .csv files, the data can be read out in a proper structured way even if they aren't separated by the commas. We just gotta change the value of separator in pd.read_sql()

# %% [markdown]
# ### sep='_'

# %%
data1 = pd.read_csv("C:\\Users\\Suryansh Grover\\downloads\\2019_data_analyst_job.csv", sep='_')
data1
# Out:
#          ID,Date,Job Title,Job Location,Hired,Easy Apply
# 0      24368,4/11/19 9:30,PHARMACEUTICAL DATA ANALYST...
# 1      24369,6/25/19 13:30,PHARMACEUTICAL DATA ANALYS...
# 2      24371,10/26/19 1:00,PHARMACEUTICAL DATA ANALYS...
# 3      24374,3/2/19 19:30,PHARMACEUTICAL DATA ANALYST...
# 4      24388,4/4/19 19:30,PHARMACEUTICAL DATA ANALYST...
# ...                                                  ...
# 32591  12154531,8/19/19 23:31,QA DATA ANALYST,"New Yo...
# 32592  12157329,3/8/19 17:50,MANUFACTURING DATA ANALY...
# 32593  12162108,10/23/19 12:05,QA DATA ANALYST,"San F...
# 32594  12165032,2/14/19 1:44,DATA QUALITY ANALYST,"Sa...
# 32595  12168373,4/6/19 15:03,NETWORK DATA ANALYST,"Ho...
#
# [32596 rows x 1 columns]

# %% [markdown]
# ### header=None i.e. first row won't be considered as Column names.

# %%
data1 = pd.read_csv("C:\\Users\\Suryansh Grover\\downloads\\2019_data_analyst_job.csv", header=None)
data1
# Out:
#               0               1                            2  \
# 0            ID            Date                    Job Title
# 1         24368    4/11/19 9:30  PHARMACEUTICAL DATA ANALYST
# 2         24369   6/25/19 13:30  PHARMACEUTICAL DATA ANALYST
# 3         24371   10/26/19 1:00  PHARMACEUTICAL DATA ANALYST
# 4         24374    3/2/19 19:30  PHARMACEUTICAL DATA ANALYST
# ...         ...             ...                          ...
# 32592  12154531   8/19/19 23:31              QA DATA ANALYST
# 32593  12157329    3/8/19 17:50   MANUFACTURING DATA ANALYST
# 32594  12162108  10/23/19 12:05              QA DATA ANALYST
# 32595  12165032    2/14/19 1:44         DATA QUALITY ANALYST
# 32596  12168373    4/6/19 15:03         NETWORK DATA ANALYST
#
#                        3      4           5
# 0           Job Location  Hired  Easy Apply
# 1             Dallas, TX  FALSE       FALSE
# 2             Austin, TX  FALSE       FALSE
# 3            Boulder, CO   TRUE       FALSE
# ...

# %% [markdown]
# ### Custom Column names

# %%
col_names=["Identification", "DATE", "Job Designation", "Loc", "Decision(Hired?)", "LinkedIn EasyApply"]
data1 = pd.read_csv("C:\\Users\\Suryansh Grover\\downloads\\2019_data_analyst_job.csv", names=col_names)
data1
# Out:
#       Identification            DATE              Job Designation  \
# 0                 ID            Date                    Job Title
# 1              24368    4/11/19 9:30  PHARMACEUTICAL DATA ANALYST
# 2              24369   6/25/19 13:30  PHARMACEUTICAL DATA ANALYST
# 3              24371   10/26/19 1:00  PHARMACEUTICAL DATA ANALYST
# 4              24374    3/2/19 19:30  PHARMACEUTICAL DATA ANALYST
# ...              ...             ...                          ...
# 32592       12154531   8/19/19 23:31              QA DATA ANALYST
# 32593       12157329    3/8/19 17:50   MANUFACTURING DATA ANALYST
# 32594       12162108  10/23/19 12:05              QA DATA ANALYST
# 32595       12165032    2/14/19 1:44         DATA QUALITY ANALYST
# 32596       12168373    4/6/19 15:03         NETWORK DATA ANALYST
#
#                      Loc Decision(Hired?) LinkedIn EasyApply
# 0           Job Location            Hired         Easy Apply
# ...

# %% [markdown]
# ### Skipping specific rows

# %%
data1 = pd.read_csv("C:\\Users\\Suryansh Grover\\downloads\\2019_data_analyst_job.csv", skiprows=[0,1,3,5,6,7,9])
data1
# Out:
#           24369   6/25/19 13:30  PHARMACEUTICAL DATA ANALYST  \
# 0         24374    3/2/19 19:30  PHARMACEUTICAL DATA ANALYST
# 1         24402   8/29/19 17:47  PHARMACEUTICAL DATA ANALYST
# 2         24430    5/9/19 11:00  PHARMACEUTICAL DATA ANALYST
# 3         24434   4/18/19 20:15  PHARMACEUTICAL DATA ANALYST
# 4         24444   10/16/19 9:44  PHARMACEUTICAL DATA ANALYST
# ...         ...             ...                          ...
# 32584  12154531   8/19/19 23:31              QA DATA ANALYST
# 32585  12157329    3/8/19 17:50   MANUFACTURING DATA ANALYST
# 32586  12162108  10/23/19 12:05              QA DATA ANALYST
# 32587  12165032    2/14/19 1:44         DATA QUALITY ANALYST
# 32588  12168373    4/6/19 15:03         NETWORK DATA ANALYST
#
#               Austin, TX  FALSE  FALSE.1
# 0           New York, NY  False    False
# 1         Richardson, TX  False    False
# 2        Santa Clara, CA  False    False
# 3      San Francisco, CA  False    False
# ...

# %% [markdown]
# ### pd.read_csv(na_values)

# %%
'''
pretty much NOT self-explanatory. You might become confused here!
Whatever value is passed in na_values parameter, all of them are supposed to be replaced by NaN.
'''
data1 = pd.read_csv("C:\\Users\\Suryansh Grover\\downloads\\2019_data_analyst_job.csv", na_values=["PHARMACEUTICAL DATA ANALYST"])
data1
# Out:
#              ID            Date                   Job Title  \
# 0         24368    4/11/19 9:30                         NaN
# 1         24369   6/25/19 13:30                         NaN
# 2         24371   10/26/19 1:00                         NaN
# 3         24374    3/2/19 19:30                         NaN
# 4         24388    4/4/19 19:30                         NaN
# ...         ...             ...                         ...
# 32591  12154531   8/19/19 23:31             QA DATA ANALYST
# 32592  12157329    3/8/19 17:50  MANUFACTURING DATA ANALYST
# 32593  12162108  10/23/19 12:05             QA DATA ANALYST
# 32594  12165032    2/14/19 1:44        DATA QUALITY ANALYST
# 32595  12168373    4/6/19 15:03        NETWORK DATA ANALYST
#
#             Job Location  Hired  Easy Apply
# 0             Dallas, TX  False       False
# 1             Austin, TX  False       False
# 2            Boulder, CO   True       False
# 3           New York, NY  False       False
# ...

# %% [markdown]
# ### Not working on "True" and "False" data vals. Why?!

# %% [markdown]
# - Check the docstring of na_values, **it won't affect the bool values even if you pass them as a string.**
# - **Actually it should be understood by common sense beacuse the values of the column you are trying to change has its datatype as BOOLEAN, th how would ya expect it to be filled by NaN vals.**

# %%
'''
pretty much self-explanatory.
'''
data2 = pd.read_csv("C:\\Users\\Suryansh Grover\\downloads\\2019_data_analyst_job.csv", na_values=[True])
data2
# Out:
#              ID            Date                    Job Title  \
# 0         24368    4/11/19 9:30  PHARMACEUTICAL DATA ANALYST
# 1         24369   6/25/19 13:30  PHARMACEUTICAL DATA ANALYST
# 2         24371   10/26/19 1:00  PHARMACEUTICAL DATA ANALYST
# 3         24374    3/2/19 19:30  PHARMACEUTICAL DATA ANALYST
# 4         24388    4/4/19 19:30  PHARMACEUTICAL DATA ANALYST
# ...         ...             ...                          ...
# 32591  12154531   8/19/19 23:31              QA DATA ANALYST
# 32592  12157329    3/8/19 17:50   MANUFACTURING DATA ANALYST
# 32593  12162108  10/23/19 12:05              QA DATA ANALYST
# 32594  12165032    2/14/19 1:44         DATA QUALITY ANALYST
# 32595  12168373    4/6/19 15:03         NETWORK DATA ANALYST
#
#             Job Location  Hired  Easy Apply
# 0             Dallas, TX  False       False
# 1             Austin, TX  False       False
# 2            Boulder, CO   True       False
# 3           New York, NY  False       False
# ...

# %% [markdown]
# ### .dtypes

# %%
data2.dtypes
# Out:
# ID               int64
# Date            object
# Job Title       object
# Job Location    object
# Hired             bool
# Easy Apply        bool
# dtype: object

# %% [markdown]
# ### .describe()

# %%
'''
Only Numerical data (by default).
'''
data2.describe()
# Out:
#                  ID
# count  3.259600e+04
# mean   1.173212e+07
# std    4.943200e+05
# min    2.436800e+04
# 25%    1.165549e+07
# 50%    1.175267e+07
# 75%    1.184793e+07
# max    1.216837e+07

# %% [markdown]
# ### .describe(include="all"): Even Categorical data is included.

# %%
data2.describe(include='all')

#top: val that has occured most.
# Out:
#                   ID            Date              Job Title  Job Location  \
# count   3.259600e+04           32596                  32596         32596
# unique           NaN           26357                     28           253
# top              NaN  11/15/19 15:30  BUSINESS DATA ANALYST  New York, NY
# freq             NaN               8                   7725          4650
# mean    1.173212e+07             NaN                    NaN           NaN
# std     4.943200e+05             NaN                    NaN           NaN
# min     2.436800e+04             NaN                    NaN           NaN
# 25%     1.165549e+07             NaN                    NaN           NaN
# 50%     1.175267e+07             NaN                    NaN           NaN
# 75%     1.184793e+07             NaN                    NaN           NaN
# max     1.216837e+07             NaN                    NaN           NaN
#
#         Hired Easy Apply
# count   32596      32596
# unique      2          2
# ...

# %% [markdown]
# ### Here's the catch we don't want that unnecssary additional index column which will be autogenerated each time .csv is saved or created by pandas. Let's try,

# %% [markdown]
# ### index=None

# %% [markdown]
# **Understand the difference:**

# %%
#1
df=pd.read_csv("analysts_data.csv", header=None)
df
# Out:
#               0               1                            2  \
# 0         24368    4/11/19 9:30  PHARMACEUTICAL DATA ANALYST
# 1         24369   6/25/19 13:30  PHARMACEUTICAL DATA ANALYST
# 2         24371   10/26/19 1:00  PHARMACEUTICAL DATA ANALYST
# 3         24374    3/2/19 19:30  PHARMACEUTICAL DATA ANALYST
# 4         24388    4/4/19 19:30  PHARMACEUTICAL DATA ANALYST
# ...         ...             ...                          ...
# 32591  12154531   8/19/19 23:31              QA DATA ANALYST
# 32592  12157329    3/8/19 17:50   MANUFACTURING DATA ANALYST
# 32593  12162108  10/23/19 12:05              QA DATA ANALYST
# 32594  12165032    2/14/19 1:44         DATA QUALITY ANALYST
# 32595  12168373    4/6/19 15:03         NETWORK DATA ANALYST
#
#                        3      4      5
# 0             Dallas, TX  False  False
# 1             Austin, TX  False  False
# 2            Boulder, CO   True  False
# 3           New York, NY  False  False
# ...

# %%
data2.to_csv("analysts_data.csv", index=None, header=None) #popped out the row containing column name.
df=pd.read_csv("analysts_data.csv")
df
# Out:
#           24368    4/11/19 9:30  PHARMACEUTICAL DATA ANALYST  \
# 0         24369   6/25/19 13:30  PHARMACEUTICAL DATA ANALYST
# 1         24371   10/26/19 1:00  PHARMACEUTICAL DATA ANALYST
# 2         24374    3/2/19 19:30  PHARMACEUTICAL DATA ANALYST
# 3         24388    4/4/19 19:30  PHARMACEUTICAL DATA ANALYST
# 4         24393   7/30/19 14:50  PHARMACEUTICAL DATA ANALYST
# ...         ...             ...                          ...
# 32590  12154531   8/19/19 23:31              QA DATA ANALYST
# 32591  12157329    3/8/19 17:50   MANUFACTURING DATA ANALYST
# 32592  12162108  10/23/19 12:05              QA DATA ANALYST
# 32593  12165032    2/14/19 1:44         DATA QUALITY ANALYST
# 32594  12168373    4/6/19 15:03         NETWORK DATA ANALYST
#
#               Dallas, TX  False  False.1
# 0             Austin, TX  False    False
# 1            Boulder, CO   True    False
# 2           New York, NY  False    False
# 3            Chicago, IL  False     True
# ...

# %%
data2.to_csv("analysts_data.csv", index=None)
pd.read_csv("analysts_data.csv")
# Out:
#              ID            Date                    Job Title  \
# 0         24368    4/11/19 9:30  PHARMACEUTICAL DATA ANALYST
# 1         24369   6/25/19 13:30  PHARMACEUTICAL DATA ANALYST
# 2         24371   10/26/19 1:00  PHARMACEUTICAL DATA ANALYST
# 3         24374    3/2/19 19:30  PHARMACEUTICAL DATA ANALYST
# 4         24388    4/4/19 19:30  PHARMACEUTICAL DATA ANALYST
# ...         ...             ...                          ...
# 32591  12154531   8/19/19 23:31              QA DATA ANALYST
# 32592  12157329    3/8/19 17:50   MANUFACTURING DATA ANALYST
# 32593  12162108  10/23/19 12:05              QA DATA ANALYST
# 32594  12165032    2/14/19 1:44         DATA QUALITY ANALYST
# 32595  12168373    4/6/19 15:03         NETWORK DATA ANALYST
#
#             Job Location  Hired  Easy Apply
# 0             Dallas, TX  False       False
# 1             Austin, TX  False       False
# 2            Boulder, CO   True       False
# 3           New York, NY  False       False
# ...

# %%
try:
    data2.to_csv("analysts_data.csv", index=False, columns=["ID", "Job Title"])
    pd.read_csv("analysts_data.csv")
except Exception as e:
    print(e)

# %%
pd.read_csv("analysts_data.csv")
# Out:
#              ID                    Job Title
# 0         24368  PHARMACEUTICAL DATA ANALYST
# 1         24369  PHARMACEUTICAL DATA ANALYST
# 2         24371  PHARMACEUTICAL DATA ANALYST
# 3         24374  PHARMACEUTICAL DATA ANALYST
# 4         24388  PHARMACEUTICAL DATA ANALYST
# ...         ...                          ...
# 32591  12154531              QA DATA ANALYST
# 32592  12157329   MANUFACTURING DATA ANALYST
# 32593  12162108              QA DATA ANALYST
# 32594  12165032         DATA QUALITY ANALYST
# 32595  12168373         NETWORK DATA ANALYST
#
# [32596 rows x 2 columns]

# %%
df1=pd.read_csv("analysts_data.csv")
df1.to_csv("analysts_data1.csv", index=None, header=None)
df2=pd.read_csv("analysts_data1.csv")
df2
# Out:
#           24368  PHARMACEUTICAL DATA ANALYST
# 0         24369  PHARMACEUTICAL DATA ANALYST
# 1         24371  PHARMACEUTICAL DATA ANALYST
# 2         24374  PHARMACEUTICAL DATA ANALYST
# 3         24388  PHARMACEUTICAL DATA ANALYST
# 4         24393  PHARMACEUTICAL DATA ANALYST
# ...         ...                          ...
# 32590  12154531              QA DATA ANALYST
# 32591  12157329   MANUFACTURING DATA ANALYST
# 32592  12162108              QA DATA ANALYST
# 32593  12165032         DATA QUALITY ANALYST
# 32594  12168373         NETWORK DATA ANALYST
#
# [32595 rows x 2 columns]

# %%
df2.to_csv("analyst_data2.csv", index=None, columns=["PHARMACEUTICAL DATA ANALYST"])
pd.read_csv("analyst_data2.csv")
# Out:
#        PHARMACEUTICAL DATA ANALYST
# 0      PHARMACEUTICAL DATA ANALYST
# 1      PHARMACEUTICAL DATA ANALYST
# 2      PHARMACEUTICAL DATA ANALYST
# 3      PHARMACEUTICAL DATA ANALYST
# 4      PHARMACEUTICAL DATA ANALYST
# ...                            ...
# 32590              QA DATA ANALYST
# 32591   MANUFACTURING DATA ANALYST
# 32592              QA DATA ANALYST
# 32593         DATA QUALITY ANALYST
# 32594         NETWORK DATA ANALYST
#
# [32595 rows x 1 columns]

# %% [markdown]
# ## In pandas, there are two types of data types we'll see:
#  - ### DataFrame
#  - ### Series (i.e. a subset of dataframe): Almost like the list datatype of core python with some exceptions, of which the most important is that negative indices don't exist in the Series.

# %% [markdown]
# ![Screenshot%20%28385%29.png](attachment:Screenshot%20%28385%29.png)

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'analysts_data.csv',
#  'analysts_data1.csv',
#  'analyst_data2.csv',
#  'data_analyst_job - Copy.csv',
#  'data_analyst_job.csv',
#  'in1__intro to pandas.ipynb']

# %%
df=pd.read_csv("data_analyst_job.csv") #having Unnamed column containing indexes.
df
# Out:
#              ID            Date                    Job Title  \
# 0         24368    4/11/19 9:30  PHARMACEUTICAL DATA ANALYST
# 1         24369   6/25/19 13:30  PHARMACEUTICAL DATA ANALYST
# 2         24371   10/26/19 1:00  PHARMACEUTICAL DATA ANALYST
# 3         24374    3/2/19 19:30  PHARMACEUTICAL DATA ANALYST
# 4         24388    4/4/19 19:30  PHARMACEUTICAL DATA ANALYST
# ...         ...             ...                          ...
# 32591  12154531   8/19/19 23:31              QA DATA ANALYST
# 32592  12157329    3/8/19 17:50   MANUFACTURING DATA ANALYST
# 32593  12162108  10/23/19 12:05              QA DATA ANALYST
# 32594  12165032    2/14/19 1:44         DATA QUALITY ANALYST
# 32595  12168373    4/6/19 15:03         NETWORK DATA ANALYST
#
#             Job Location  Hired  Easy Apply
# 0             Dallas, TX  False       False
# 1             Austin, TX  False       False
# 2            Boulder, CO   True       False
# 3           New York, NY  False       False
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Date', 'Job Title', 'Job Location', 'Hired', 'Easy Apply'], dtype='object')

# %%
df['Job Title']
# Out:
# 0        PHARMACEUTICAL DATA ANALYST
# 1        PHARMACEUTICAL DATA ANALYST
# 2        PHARMACEUTICAL DATA ANALYST
# 3        PHARMACEUTICAL DATA ANALYST
# 4        PHARMACEUTICAL DATA ANALYST
#                     ...
# 32591                QA DATA ANALYST
# 32592     MANUFACTURING DATA ANALYST
# 32593                QA DATA ANALYST
# 32594           DATA QUALITY ANALYST
# 32595           NETWORK DATA ANALYST
# Name: Job Title, Length: 32596, dtype: object

# %% [markdown]
# ### Slicing and Indexing and what not we can do with the lists, same is possible with the Series.

# %%
df['Job Title'][:50]
# Out:
# 0     PHARMACEUTICAL DATA ANALYST
# 1     PHARMACEUTICAL DATA ANALYST
# 2     PHARMACEUTICAL DATA ANALYST
# 3     PHARMACEUTICAL DATA ANALYST
# 4     PHARMACEUTICAL DATA ANALYST
# 5     PHARMACEUTICAL DATA ANALYST
# 6     PHARMACEUTICAL DATA ANALYST
# 7     PHARMACEUTICAL DATA ANALYST
# 8     PHARMACEUTICAL DATA ANALYST
# 9     PHARMACEUTICAL DATA ANALYST
# 10    PHARMACEUTICAL DATA ANALYST
# 11    PHARMACEUTICAL DATA ANALYST
# 12    PHARMACEUTICAL DATA ANALYST
# 13    PHARMACEUTICAL DATA ANALYST
# 14    PHARMACEUTICAL DATA ANALYST
# 15    PHARMACEUTICAL DATA ANALYST
# 16    PHARMACEUTICAL DATA ANALYST
# 17    PHARMACEUTICAL DATA ANALYST
# 18    PHARMACEUTICAL DATA ANALYST
# 19    PHARMACEUTICAL DATA ANALYST
# 20    PHARMACEUTICAL DATA ANALYST
# 21    PHARMACEUTICAL DATA ANALYST
# 22    PHARMACEUTICAL DATA ANALYST
# 23    PHARMACEUTICAL DATA ANALYST
# 24    PHARMACEUTICAL DATA ANALYST
# 25    PHARMACEUTICAL DATA ANALYST
# 26    PHARMACEUTICAL DATA ANALYST
# ...

# %%
try:
    print(df['Job Title'][::-1])
except Exception as e:
    print(e)
# Out:
# 32595           NETWORK DATA ANALYST
# 32594           DATA QUALITY ANALYST
# 32593                QA DATA ANALYST
# 32592     MANUFACTURING DATA ANALYST
# 32591                QA DATA ANALYST
#                     ...
# 4        PHARMACEUTICAL DATA ANALYST
# 3        PHARMACEUTICAL DATA ANALYST
# 2        PHARMACEUTICAL DATA ANALYST
# 1        PHARMACEUTICAL DATA ANALYST
# 0        PHARMACEUTICAL DATA ANALYST
# Name: Job Title, Length: 32596, dtype: object

# %% [markdown]
# ### Since we know negative indices don't exist in the Series.

# %%
df['Job Title'][-1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     384                 try:
# --> 385                     return self._range.index(new_key)
#     386                 except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# C:\Users\SURYAN~1\AppData\Local\Temp/ipykernel_13660/2580633568.py in <module>
# ----> 1 df['Job Title'][-1]
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     940
#     941         elif key_is_scalar:
# --> 942             return self._get_value(key)
#     943
#     944         if is_hashable(key):
#
# ...

# %% [markdown]
# ### Types: DataFrame, Series

# %%
type(df), type(df['Job Title'])
# Out:
# (pandas.core.frame.DataFrame, pandas.core.series.Series)

# %% [markdown]
# ### Converting series datatype into the DataFrame datatype:

# %%
df[['Job Title']]
# Out:
#                          Job Title
# 0      PHARMACEUTICAL DATA ANALYST
# 1      PHARMACEUTICAL DATA ANALYST
# 2      PHARMACEUTICAL DATA ANALYST
# 3      PHARMACEUTICAL DATA ANALYST
# 4      PHARMACEUTICAL DATA ANALYST
# ...                            ...
# 32591              QA DATA ANALYST
# 32592   MANUFACTURING DATA ANALYST
# 32593              QA DATA ANALYST
# 32594         DATA QUALITY ANALYST
# 32595         NETWORK DATA ANALYST
#
# [32596 rows x 1 columns]

# %%
type(df[['Job Title']])
# Out:
# pandas.core.frame.DataFrame

# %%
df[['Job Title', 'Job Location']]
# Out:
#                          Job Title       Job Location
# 0      PHARMACEUTICAL DATA ANALYST         Dallas, TX
# 1      PHARMACEUTICAL DATA ANALYST         Austin, TX
# 2      PHARMACEUTICAL DATA ANALYST        Boulder, CO
# 3      PHARMACEUTICAL DATA ANALYST       New York, NY
# 4      PHARMACEUTICAL DATA ANALYST        Chicago, IL
# ...                            ...                ...
# 32591              QA DATA ANALYST       New York, NY
# 32592   MANUFACTURING DATA ANALYST        Chicago, IL
# 32593              QA DATA ANALYST  San Francisco, CA
# 32594         DATA QUALITY ANALYST      San Diego, CA
# 32595         NETWORK DATA ANALYST        Houston, TX
#
# [32596 rows x 2 columns]

# %% [markdown]
# ## Reading the Excel files:

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'analysts_data.csv',
#  'analysts_data1.csv',
#  'analyst_data2.csv',
#  'data_analyst_job - Copy.csv',
#  'data_analyst_job.csv',
#  'fsi-2021.xlsx',
#  'in1__intro to pandas.ipynb',
#  'ir211wk12sample.xls']

# %%
pd.read_excel("fsi-2021.xlsx")
# Out:
#                        Country  Year   Rank  Total  C1: Security Apparatus  \
# 0                        Yemen  2021    1st  111.7                     9.4
# 1                      Somalia  2021    2nd  110.9                     9.3
# 2                        Syria  2021    3rd  110.7                     9.6
# 3                  South Sudan  2021    4th  109.4                     9.7
# 4    Congo Democratic Republic  2021    5th  108.4                     8.6
# ..                         ...   ...    ...    ...                     ...
# 174                    Denmark  2021  175th   18.8                     1.7
# 175                New Zealand  2021  176th   18.4                     1.4
# 176                    Iceland  2021  177th   18.0                     0.7
# 177                     Norway  2021  178th   16.6                     1.8
# 178                    Finland  2021  179th   16.2                     2.5
#
#      C2: Factionalized Elites  C3: Group Grievance  E1: Economy  \
# ...

# %%
pd.read_excel("ir211wk12sample.xls")
# Out:
#     OrderDate   Region       Rep     Item      Units   Unit Cost        Total  \
# 0  2014-09-01  Central     Smith     Desk   2.000000  125.000000   250.000000
# 1  2015-06-17  Central    Kivell     Desk   5.000000  125.000000   625.000000
# 2  2015-09-10  Central      Gill   Pencil   7.000000    1.290000     9.030000
# 3  2015-11-17  Central   Jardine   Binder  11.000000    4.990000    54.890000
# 4  2015-10-31  Central   Andrews   Pencil  14.000000    1.290000    18.060000
# 5  2014-02-26  Central      Gill      Pen  27.000000   19.990000   539.730000
# 6  2014-10-05  Central    Morgan   Binder  28.000000    8.990000   251.720000
# 7  2015-12-21  Central   Andrews   Binder  28.000000    4.990000   139.720000
# 8  2014-02-09  Central   Jardine   Pencil  36.000000    4.990000   179.640000
# 9  2015-08-07  Central    Kivell  Pen Set  42.000000   23.950000  1005.900000
# 10 2015-01-15  Central      Gill   Binder  46.000000    8.990000   413.540000
# ...

# %%
pd.read_excel("ir211wk12sample.xls", sheet_name='MyLinks')
# Out:
#     Unnamed: 0                                Unnamed: 1  \
# 0          NaN                      Contextures Products
# 1          NaN                                       NaN
# 2          NaN                 PivotPower Premium Add-in
# 3          NaN        UserForms for Data Entry ebook Kit
# 4          NaN            Contextures Excel Tools Add-in
# 5          NaN  Data Validation Multi-Select Premium Kit
# 6          NaN   30 Excel Functions in 30 Days eBook Kit
# 7          NaN                                       NaN
# 8          NaN                    Contextures Recommends
# 9          NaN                                       NaN
# 10         NaN       Jon Peltier's Excel Chart Utilities
# 11         NaN                      ExcelUser Dashboards
# 12         NaN                 Xtreme Pivot Table Course
# 13         NaN                    Power Pivot University
# 14         NaN                      Excel Courses Online
# ...

# %% [markdown]
# ## Reading a web page i.e. .html file:

# %%
try:
    pd.read_html("https://www.netflix.com/in/title/80002479")
except Exception as e:
    print(e)
# Out:
# No tables found

# %%
try:
    df=pd.read_html("https://www.basketball-reference.com/")
except Exception as e:
    print(e)

# %% [markdown]
# ### by default we'll get only tabular data from html pages.

# %%
df
# Out:
# [          East Unnamed: 1 Unnamed: 2   W   L
#  0    MIA * (1)          F          $  53  29
#  1    BOS * (2)          F          $  51  31
#  2    MIL * (3)          F          $  51  31
#  3    PHI * (4)          F          $  51  31
#  4    TOR * (5)          F          $  48  34
#  5    CHI * (6)          F          $  46  36
#  6    BRK * (7)          F          $  44  38
#  7    CLE x (8)          F          $  44  38
#  8    ATL * (9)          F          $  43  39
#  9   CHO x (10)          F          $  43  39
#  10  NYK x (11)          F          $  37  45
#  11  WAS x (12)          F          $  35  47
#  12  IND x (13)          F          $  25  57
#  13  DET x (14)          F          $  23  59
#  14  ORL x (15)          F          $  22  60,
#            West Unnamed: 1 Unnamed: 2   W   L
#  0    PHO * (1)          F          $  64  18
#  1    MEM * (2)          F          $  56  26
#  2    GSW * (3)          F          $  53  29
# ...

# %%
type(df)
# Out:
# list

# %%
len(df)
# Out:
# 23

# %%
df[0]
# Out:
#           East Unnamed: 1 Unnamed: 2   W   L
# 0    MIA * (1)          F          $  53  29
# 1    BOS * (2)          F          $  51  31
# 2    MIL * (3)          F          $  51  31
# 3    PHI * (4)          F          $  51  31
# 4    TOR * (5)          F          $  48  34
# 5    CHI * (6)          F          $  46  36
# 6    BRK * (7)          F          $  44  38
# 7    CLE x (8)          F          $  44  38
# 8    ATL * (9)          F          $  43  39
# 9   CHO x (10)          F          $  43  39
# 10  NYK x (11)          F          $  37  45
# 11  WAS x (12)          F          $  35  47
# 12  IND x (13)          F          $  25  57
# 13  DET x (14)          F          $  23  59
# 14  ORL x (15)          F          $  22  60

# %%
df[22]
# Out:
#   Unnamed: 0_level_0 Knockout Stage
#                 Team              W  L   W/L%
# 0              Spain              3  0  1.000
# 1             France              2  1  0.667
# 2          Argentina              2  1  0.667
# 3          Australia              1  2  0.333
# 4      United States              0  1  0.000
# 5             Poland              0  1  0.000
# 6             Serbia              0  1  0.000
# 7     Czech Republic              0  1  0.000

# %%
type(df[22])
# Out:
# pandas.core.frame.DataFrame

# %%
pd.read_csv("titanic.csv")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## .json

# %%
s = """{
"Namae wa": "Ashura",
"desig": "warrior",
"rank": 2,
"age": 52,
"anything_else": ["lets", "do", "whatever we feel like", 1999]
}
"""
print(s)
# Out:
# {
# "Namae wa": "Ashura",
# "desig": "warrior",
# "rank": 2,
# "age": 52,
# "anything_else": ["lets", "do", "whatever we feel like", 1999]
# }

# %%
import json

# %%
s1=json.loads(s)
s1
# Out:
# {'Namae wa': 'Ashura',
#  'desig': 'warrior',
#  'rank': 2,
#  'age': 52,
#  'anything_else': ['lets', 'do', 'whatever we feel like', 1999]}

# %%
pd.DataFrame(s1)
# Out:
#   Namae wa    desig  rank  age          anything_else
# 0   Ashura  warrior     2   52                   lets
# 1   Ashura  warrior     2   52                     do
# 2   Ashura  warrior     2   52  whatever we feel like
# 3   Ashura  warrior     2   52                   1999

# %%
# !pip install requests

# %%
import requests

# %% [markdown]
# **The requests module allows you to send HTTP requests using Python. The HTTP request returns a Response Object with all the response data (content, encoding, status, etc).**

# %%
resa=requests.get("https://api.github.com/repos/pandas-dev/pandas/issues")

# %%
j_data=resa.json()

# %%
pd.DataFrame(j_data)
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
len(j_data)
# Out:
# 30

# %%
j_data[0]
# Out:
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47540',
#  'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#  'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47540/labels{/name}',
#  'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47540/comments',
#  'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47540/events',
#  'html_url': 'https://github.com/pandas-dev/pandas/pull/47540',
#  'id': 1288001165,
#  'node_id': 'PR_kwDOAA0YD846h6hh',
#  'number': 47540,
#  'title': 'DOC: Convert URL example to static code block',
#  'user': {'login': 'mroeschke',
#   'id': 10647082,
#   'node_id': 'MDQ6VXNlcjEwNjQ3MDgy',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/mroeschke',
#   'html_url': 'https://github.com/mroeschke',
#   'followers_url': 'https://api.github.com/users/mroeschke/followers',
# ...

# %%
j_data[1]
# Out:
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47396',
#  'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#  'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47396/labels{/name}',
#  'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47396/comments',
#  'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47396/events',
#  'html_url': 'https://github.com/pandas-dev/pandas/pull/47396',
#  'id': 1274425249,
#  'node_id': 'PR_kwDOAA0YD8450lT9',
#  'number': 47396,
#  'title': 'REF: do masking in checked_add_with_arr',
#  'user': {'login': 'jbrockmendel',
#   'id': 8078968,
#   'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/jbrockmendel',
#   'html_url': 'https://github.com/jbrockmendel',
#   'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
# ...

# %%
for i in j_data:
    print(i)
    print("-----------------------------------------------------------------------------------------------------------")
# Out:
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47397', 'repository_url': 'https://api.github.com/repos/pandas-dev/pandas', 'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47397/labels{/name}', 'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47397/comments', 'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47397/events', 'html_url': 'https://github.com/pandas-dev/pandas/pull/47397', 'id': 1274745584, 'node_id': 'PR_kwDOAA0YD8451qd0', 'number': 47397, 'title': 'BUG: read_csv may interpret second row as index names even if index_col is False', 'user': {'login': 'phofl', 'id': 61934744, 'node_id': 'MDQ6VXNlcjYxOTM0NzQ0', 'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/phofl', 'html_url': 'https://github.com/phofl', 'followers_url': 'https://api.github.com/users/phofl/followers', 'following_url': 'https://api.github.com/users/phofl/f
# ...

# %% [markdown]
# ## fetching the key 'title' from the json data:

# %%
for i in range(len(j_data)):
    print(j_data[i]['title'])
# Out:
# BUG: read_csv may interpret second row as index names even if index_col is False
# REF: do masking in checked_add_with_arr
# implement abbrev_to_npy_unit
# ENH: consistent add/sub behavior for mixed resolutions
# CI/TST: Don't require length for construct_1d_arraylike_from_scalar cast to float64
# CI: nighlty numpy broke ci
# Consistent handling of 0-dim in Timedelta arithmetic methods
# DOC: update tutorials.rst to include website for searchable Pandas recipes
# TST,WARN: read_csv raises warning at wrong stacklevel, but _assert_raised_with_correct_stacklevel doesn't fail
# Is there a bug in pandas: "Cannot set a frame with no defined index and a value that cannot be converted to a Series"?
# TST,WARN: read_csv raises warning at wrong stacklevel, but _assert_raised_with_correct_stacklevel doesn't fail
# DOC: Breaking change for join, int to float type coercion
# Mixed dtypes of column index for data frames raises en error
# New behaviour regarding inplace values setting with iloc
# ...

# %%
for i in j_data:
    print(i["title"])
    print("-----------------------------------------------------------------------------------------------------------")
# Out:
# BUG: read_csv may interpret second row as index names even if index_col is False
# -----------------------------------------------------------------------------------------------------------
# REF: do masking in checked_add_with_arr
# -----------------------------------------------------------------------------------------------------------
# implement abbrev_to_npy_unit
# -----------------------------------------------------------------------------------------------------------
# ENH: consistent add/sub behavior for mixed resolutions
# -----------------------------------------------------------------------------------------------------------
# CI/TST: Don't require length for construct_1d_arraylike_from_scalar cast to float64
# -----------------------------------------------------------------------------------------------------------
# CI: nighlty numpy broke ci
# -----------------------------------------------------------------------------------------------------------
# ...

# %%
for i in range(len(j_data)):
    print(f"{i}: \n", j_data[i]['user'])
# Out:
# 0:
#  {'login': 'phofl', 'id': 61934744, 'node_id': 'MDQ6VXNlcjYxOTM0NzQ0', 'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/phofl', 'html_url': 'https://github.com/phofl', 'followers_url': 'https://api.github.com/users/phofl/followers', 'following_url': 'https://api.github.com/users/phofl/following{/other_user}', 'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions', 'organizations_url': 'https://api.github.com/users/phofl/orgs', 'repos_url': 'https://api.github.com/users/phofl/repos', 'events_url': 'https://api.github.com/users/phofl/events{/privacy}', 'received_events_url': 'https://api.github.com/users/phofl/received_events', 'type': 'User', 'site_admin': False}
# 1:
# ...

# %%
for i in j_data:
    print(i["user"])
    print("-----------------------------------------------------------------------------------------------------------")
# Out:
# {'login': 'phofl', 'id': 61934744, 'node_id': 'MDQ6VXNlcjYxOTM0NzQ0', 'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/phofl', 'html_url': 'https://github.com/phofl', 'followers_url': 'https://api.github.com/users/phofl/followers', 'following_url': 'https://api.github.com/users/phofl/following{/other_user}', 'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions', 'organizations_url': 'https://api.github.com/users/phofl/orgs', 'repos_url': 'https://api.github.com/users/phofl/repos', 'events_url': 'https://api.github.com/users/phofl/events{/privacy}', 'received_events_url': 'https://api.github.com/users/phofl/received_events', 'type': 'User', 'site_admin': False}
# ...

# %%
pd.DataFrame(j_data, columns=['title', 'users'])
# Out:
#                                                 title  users
# 0   BUG: read_csv may interpret second row as inde...    NaN
# 1             REF: do masking in checked_add_with_arr    NaN
# 2                        implement abbrev_to_npy_unit    NaN
# 3   ENH: consistent add/sub behavior for mixed res...    NaN
# 4   CI/TST: Don't require length for construct_1d_...    NaN
# 5                          CI: nighlty numpy broke ci    NaN
# 6   Consistent handling of 0-dim in Timedelta arit...    NaN
# 7   DOC: update tutorials.rst to include website f...    NaN
# 8   TST,WARN: read_csv raises warning at wrong sta...    NaN
# 9   Is there a bug in pandas: "Cannot set a frame ...    NaN
# 10  TST,WARN: read_csv raises warning at wrong sta...    NaN
# 11  DOC: Breaking change for join, int to float ty...    NaN
# 12  Mixed dtypes of column index for data frames r...    NaN
# 13  New behaviour regarding inplace values setting...    NaN
# ...

# %% [markdown]
# ## Task:

# %% [markdown]
# ## fetch all the users data and display it in tabular form(DataFrame):

# %%
#1
users_data={}
for i in j_data:
    for j in i["user"]:
        users_data[j] = []
print(users_data)
#2
for i in range(len(j_data)):
    for j in j_data[i]['user']: #parsing each dictionary.
        x = j_data[i]['user'][j] #parsing each key of the sub dictionary.
        users_data[j].append(x)
users_data
# Out:
# {'login': [], 'id': [], 'node_id': [], 'avatar_url': [], 'gravatar_id': [], 'url': [], 'html_url': [], 'followers_url': [], 'following_url': [], 'gists_url': [], 'starred_url': [], 'subscriptions_url': [], 'organizations_url': [], 'repos_url': [], 'events_url': [], 'received_events_url': [], 'type': [], 'site_admin': []}
# {'login': ['mroeschke',
#   'wangjoshuah',
#   'jbrockmendel',
#   'mroeschke',
#   'mroeschke',
#   'INDIG0N',
#   'jtpio',
#   'datapythonista',
#   'easysam',
#   'behrenhoff',
#   'Codeberg-AsGithubAlternative-buhtz',
#   'Codeberg-AsGithubAlternative-buhtz',
#   'mroeschke',
#   'twoertwein',
#   'K20shores',
#   'MarcoGorelli',
#   'mroeschke',
#   'mroeschke',
#   'MarcoGorelli',
#   'MarcoGorelli',
#   'phofl',
#   'rhshadrach',
#   'FlorinAndrei',
#   'vyasr',
#   'rhshadrach',
#   'MarcoGorelli',
#   'phofl',
#   'mousey92',
#   'DRudel',
#   'vnlitvinov'],
#  'id': [10647082,
#   5353594,
#   8078968,
#   10647082,
#   10647082,
#   66040891,
# ...

# %%
type(users_data)
# Out:
# dict

# %%
users_df=pd.DataFrame(users_data) 
users_df
# Out:
#                  login        id               node_id  \
# 0                phofl  61934744  MDQ6VXNlcjYxOTM0NzQ0
# 1         jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 2         jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 3         jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 4            mroeschke  10647082  MDQ6VXNlcjEwNjQ3MDgy
# 5                phofl  61934744  MDQ6VXNlcjYxOTM0NzQ0
# 6         jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 7       TraverseTowner  16629450  MDQ6VXNlcjE2NjI5NDUw
# 8         MarcoGorelli  33491632  MDQ6VXNlcjMzNDkxNjMy
# 9             DonSeger  94080584          U_kgDOBZuOSA
# 10        MarcoGorelli  33491632  MDQ6VXNlcjMzNDkxNjMy
# 11            oxlade39    144005  MDQ6VXNlcjE0NDAwNQ==
# 12   ChristopheBernard  14012015  MDQ6VXNlcjE0MDEyMDE1
# 13           glemaitre   7454015  MDQ6VXNlcjc0NTQwMTU=
# 14             WillAyd    609873  MDQ6VXNlcjYwOTg3Mw==
# 15          twoertwein   6618166  MDQ6VXNlcjY2MTgxNjY=
# ...

# %%
users_df.to_csv("users_data.csv", index=None)

# %% [markdown]
# ### Another Approach:

# %%
lis=[]
for i in range(len(j_data)):
    lis.append(j_data[i]['user'])
lis
# Out:
# [{'login': 'phofl',
#   'id': 61934744,
#   'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/phofl',
#   'html_url': 'https://github.com/phofl',
#   'followers_url': 'https://api.github.com/users/phofl/followers',
#   'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#   'organizations_url': 'https://api.github.com/users/phofl/orgs',
#   'repos_url': 'https://api.github.com/users/phofl/repos',
#   'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/phofl/received_events',
#   'type': 'User',
#   'site_admin': False},
# ...

# %%
pd.DataFrame(lis)
# Out:
#                  login        id               node_id  \
# 0                phofl  61934744  MDQ6VXNlcjYxOTM0NzQ0
# 1         jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 2         jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 3         jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 4            mroeschke  10647082  MDQ6VXNlcjEwNjQ3MDgy
# 5                phofl  61934744  MDQ6VXNlcjYxOTM0NzQ0
# 6         jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 7       TraverseTowner  16629450  MDQ6VXNlcjE2NjI5NDUw
# 8         MarcoGorelli  33491632  MDQ6VXNlcjMzNDkxNjMy
# 9             DonSeger  94080584          U_kgDOBZuOSA
# 10        MarcoGorelli  33491632  MDQ6VXNlcjMzNDkxNjMy
# 11            oxlade39    144005  MDQ6VXNlcjE0NDAwNQ==
# 12   ChristopheBernard  14012015  MDQ6VXNlcjE0MDEyMDE1
# 13           glemaitre   7454015  MDQ6VXNlcjc0NTQwMTU=
# 14             WillAyd    609873  MDQ6VXNlcjYwOTg3Mw==
# 15          twoertwein   6618166  MDQ6VXNlcjY2MTgxNjY=
# ...
