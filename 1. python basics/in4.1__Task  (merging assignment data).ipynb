# %%
pwd
# Out:
# 'C:\\Users\\Suryansh Grover\\iNeuron\\1. python basics'

# %%
import os
os.chdir("C:\\Users\\Suryansh Grover\\downloads\\new folder")

# %%
pwd()
# Out:
# 'C:\\Users\\Suryansh Grover\\downloads\\new folder'

# %%
os.listdir()
# Out:
# ['Assignment_1 (2).docx',
#  'Assignment_1.docx',
#  'Assignment_10 (2).docx',
#  'Assignment_10.docx',
#  'Assignment_11 (2).docx',
#  'Assignment_11.docx',
#  'Assignment_12 (2).docx',
#  'Assignment_12.docx',
#  'Assignment_13 (2).docx',
#  'Assignment_13.docx',
#  'Assignment_14 (2).docx',
#  'Assignment_14.docx',
#  'Assignment_15 (2).docx',
#  'Assignment_15.docx',
#  'Assignment_16 (2).docx',
#  'Assignment_16.docx',
#  'Assignment_17 (2).docx',
#  'Assignment_17.docx',
#  'Assignment_18 (2).docx',
#  'Assignment_18.docx',
#  'Assignment_19 (2).docx',
#  'Assignment_19.docx',
#  'Assignment_2 (2).docx',
#  'Assignment_2.docx',
#  'Assignment_20 (2).docx',
#  'Assignment_20.docx',
#  'Assignment_21 (2).docx',
#  'Assignment_21.docx',
#  'Assignment_22 (2).docx',
#  'Assignment_22.docx',
#  'Assignment_23 (2).docx',
#  'Assignment_23.docx',
#  'Assignment_24 (2).docx',
#  'Assignment_24.docx',
#  'Assignment_25 (2).docx',
#  'Assignment_25.docx',
#  'Assignment_3 (2).docx',
# ...

# %%
os.mkdir('C:\\Users\\Suryansh Grover\\downloads\\Assignments (iNeuron)')

# %%
import shutil

# %%
for i in os.listdir():
    shutil.move(i,'C:\\Users\\Suryansh Grover\\downloads\\Assignments (iNeuron)')

# %%
os.chdir('C:\\Users\\Suryansh Grover\\downloads\\Assignments (iNeuron)')

# %%
'string' in 'string_1'
os.renames
# Out:
# True

# %% [markdown]
# # Reading the .docx files:

# %%
 pip install python-docx
# Out:
# ...
#   Created wheel for python-docx: filename=python_docx-0.8.11-py3-none-any.whl size=184508 sha256=e61a50f2f7398d5a0d2bb2af8c0f8bee013798dd34a76c9b5d82f2fdbedbdf7d
#   Stored in directory: c:\users\suryansh grover\appdata\local\pip\cache\wheels\83\8b\7c\09ae60c42c7ba4ed2dddaf2b8b9186cb105255856d6ed3dba5
# Successfully built python-docx
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import docx

# %%
doc = docx.Document('Assignment_1.docx')

# %%
doc.paragraphs

# %%
doc.paragraphs[0].text
# Out:
# '1. In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.'

# %%
len(doc.paragraphs)
# Out:
# 815

# %%
ass = docx.Document()

# %%
for i in range(len(doc.paragraphs)):
    ass.add_paragraph(doc.paragraphs[i].text)

# %%
doc.save('Assignments_merged.docx')

# %%
os.rename('Assignment_111.docx', 'Assignment_1 (2).docx' )
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\Users\SURYAN~1\AppData\Local\Temp/ipykernel_8832/637585050.py in <module>
# ----> 1 os.rename('Assignment_111.docx', 'Assignment_1 (2).docx' )
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'Assignment_111.docx' -> 'Assignment_1 (2).docx'

# %%
def rename_if(files):
    
    for i in files:
        pass

# %%
pwd(0)
# Out:
# 'C:\\Users\\Suryansh Grover\\downloads\\Assignments (iNeuron)'

# %% [markdown]
# ## Copying all the data from all the regular assignments and dumping it into one single file.

# %%
os.listdir()
# Out:
# ['Assignments_merged.docx',
#  'Assignment_1 (2).docx',
#  'Assignment_1.docx',
#  'Assignment_10 (2).docx',
#  'Assignment_10.docx',
#  'Assignment_11 (2).docx',
#  'Assignment_11.docx',
#  'Assignment_12 (2).docx',
#  'Assignment_12.docx',
#  'Assignment_13 (2).docx',
#  'Assignment_13.docx',
#  'Assignment_14 (2).docx',
#  'Assignment_14.docx',
#  'Assignment_15 (2).docx',
#  'Assignment_15.docx',
#  'Assignment_16 (2).docx',
#  'Assignment_16.docx',
#  'Assignment_17 (2).docx',
#  'Assignment_17.docx',
#  'Assignment_18 (2).docx',
#  'Assignment_18.docx',
#  'Assignment_19 (2).docx',
#  'Assignment_19.docx',
#  'Assignment_2 (2).docx',
#  'Assignment_2.docx',
#  'Assignment_20 (2).docx',
#  'Assignment_20.docx',
#  'Assignment_21 (2).docx',
#  'Assignment_21.docx',
#  'Assignment_22 (2).docx',
#  'Assignment_22.docx',
#  'Assignment_23 (2).docx',
#  'Assignment_23.docx',
#  'Assignment_24 (2).docx',
#  'Assignment_24.docx',
#  'Assignment_25 (2).docx',
#  'Assignment_25.docx',
# ...

# %%
asg = docx.Document()
for i in os.listdir():
    if 'Assignment' in i:
        doc = docx.Document(i)
        asg.add_paragraph("\n")
        asg.add_heading(i)
        asg.add_paragraph("\n")
        for j in range(len(doc.paragraphs)):
                asg.add_paragraph(doc.paragraphs[j].text)
asg.save("Merged (regular assignments).docx")


pro_asg = docx.Document()
for i in os.listdir():
    if 'Programming' in i:
        doc = docx.Document(i)
        asg.add_paragraph("\n")
        pro_asg.add_heading(i) #Title
        asg.add_paragraph("\n")
        for j in range(len(doc.paragraphs)):
            pro_asg.add_paragraph(doc.paragraphs[j].text)
pro_asg.save('Merged (Programming Assignments).docx')

# %%
doc = docx.Document('Merged (regular assignments).docx')
for i in range(len(doc.paragraphs)):
               print(doc.paragraphs[i].text)
# Out:
# Assignments_merged.docx
#
#
# 1. In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.
# *
# 'hello'
# -87.8
# -
# /
#
# 6
#
# 2. What is the difference between string and variable?
#
# 3. Describe three different data types.
#
# 4. What is an expression made up of? What do all expressions do?
# 5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?
# 6. After running the following code, what does the variable bacon contain?
# bacon = 22
# bacon + 1
#
# 7. What should the values of the following two terms be?
# 'spam' + 'spamspam'
# 'spam' * 3
#
# 8. Why is eggs a valid variable name while 100 is invalid?
# 9. What three functions can be used to get the integer, floating-point number, or string version of a value?
# 10. Why does this expression cause an error? How can you fix it?
# 'I have eaten ' + 99 + ' burritos.'
#
#
#
#
# ...

# %%
doc = docx.Document('Merged (Programming Assignments).docx')
for i in range(len(doc.paragraphs)):
               print(doc.paragraphs[i].text)
# Out:
# Programming_Assingment1.docx
# Write a Python program to print "Hello Python"?
# Write a Python program to do arithmetical operations addition and division.?
# Write a Python program to find the area of a triangle?
# Write a Python program to swap two variables?
# Write a Python program to generate a random number?
# Programming_Assingment10.docx
# Write a Python program to find sum of elements in list?
# Write a Python program to  Multiply all numbers in the list?
# Write a Python program to find smallest number in a list?
# Write a Python program to find largest number in a list?
# Write a Python program to find second largest number in a list?
# Write a Python program to find N largest elements from a list?
# Write a Python program to print even numbers in a list?
# Write a Python program to print odd numbers in a List?
# Write a Python program to Remove empty List from List?
# Write a Python program to Cloning or Copying a list?
# ...

# %%
pwd()
# Out:
# 'C:\\Users\\Suryansh Grover\\Downloads\\Assignments (iNeuron)'

# %%
os.mkdir('Merged')

# %%
import shutil

# %%
shutil.move('Merged (regular assignments).docx', 'Merged')
shutil.move('Merged (Programming Assignments).docx', 'Merged')
# Out:
# 'Merged\\Merged (Programming Assignments).docx'

# %%
os.chdir('Merged')
os.listdir()
# Out:
# ['Merged (Programming Assignments).docx', 'Merged (regular assignments).docx']

# %% [markdown]
# # Dumping all the assignments data in a .txt file.

# %%
pwd
# Out:
# 'C:\\Users\\Suryansh Grover\\iNeuron\\1. python basics'

# %%
import os, docx
os.chdir("C:\\Users\\Suryansh Grover\\Downloads\\New Folder")

# %%
os.chdir("C:\\Users\\Suryansh Grover\\Downloads\\New Folder")
f = open("Merged (regular)_1.txt", 'a')
p = open("Merged (Pro)_2.txt", 'a')

# %%
for i in os.listdir():
    
    if 'Assignment' in i:
        doc = docx.Document(i)
        f.write('\n')
        f.writelines(i)
        f.write('\n')
        for j in range(len(doc.paragraphs)):
            f.writelines(doc.paragraphs[j].text)
            f.write('\n')  
f.close()

# %%
for i in os.listdir():
    
    if 'Programming' in i:
        doc1 = docx.Document(i)
        p.writelines('\n')
        p.writelines(i)
        p.writelines('\n')
        for j in range(len(doc1.paragraphs)):
            p.writelines(doc1.paragraphs[j].text)
            p.writelines('\n')

p.close()
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# C:\Users\SURYAN~1\AppData\Local\Temp/ipykernel_19792/1907483509.py in <module>
#       7         p.writelines('\n')
#       8         for j in range(len(doc1.paragraphs)):
# ----> 9             p.writelines(doc1.paragraphs[j].text)
#      10             p.writelines('\n')
#      11
#
# ~\anaconda3\lib\encodings\cp1252.py in encode(self, input, final)
#      17 class IncrementalEncoder(codecs.IncrementalEncoder):
#      18     def encode(self, input, final=False):
# ---> 19         return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#      20
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#
# UnicodeEncodeError: 'charmap' codec can't encode character '\u279e' in position 0: character maps to <undefined>

# %%
os.chdir("C:\\Users\\Suryansh Grover\\Downloads\\Assignments (iNeuron)")
doc1 = docx.Document('Programming_Assingment1.docx')

# %%
for i in range(len(doc1.paragraphs)):
    print(doc1.paragraphs[i].text)
# Out:
# Write a Python program to print "Hello Python"?
# Write a Python program to do arithmetical operations addition and division.?
# Write a Python program to find the area of a triangle?
# Write a Python program to swap two variables?
# Write a Python program to generate a random number?

# %%
g = open("Merged (regular).txt", "r")

# %%
g.read()
g.seek(0)
# Out:
# 0

# %%
g.readlines()
# Out:
# ['\n',
#  'Assignments_merged.docx\n',
#  '1. In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.\n',
#  '* \n',
#  "'hello'\n",
#  '-87.8\n',
#  '- \n',
#  '/ \n',
#  '\n',
#  '6 \n',
#  '\n',
#  '2. What is the difference between string and variable?\n',
#  '\n',
#  '3. Describe three different data types.\n',
#  '\n',
#  '4. What is an expression made up of? What do all expressions do?\n',
#  '5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?\n',
#  '6. After running the following code, what does the variable bacon contain?\n',
#  'bacon = 22\n',
#  'bacon + 1\n',
#  '\n',
#  '7. What should the values of the following two terms be?\n',
#  "'spam' + 'spamspam'\n",
#  "'spam' * 3\n",
#  '\n',
#  '8. Why is eggs a valid variable name while 100 is invalid?\n',
# ...

# %%
import os

# %%
os.path.isdir(os.getcwd() + '//ineuron')
# Out:
# False

# %%
pwd()
# Out:
# 'C:\\Users\\Suryansh Grover\\Downloads\\Assignments (iNeuron)\\Merged'

# %%
def rename(file_name, ext = '.docx'):
    """
    Renaming the files so that they don't have any '(' and ')' in them.
    """
    cut_len = 0
    #pdb.set_trace()
    for i in range(len(file_name)):
        if file_name[i].isnumeric():
            cut_len = i
            for j in range(i, len(file_name)):
                if not file_name[j].isnumeric():
                    cut_len1 = j
                    break
            break
    
    #print(cut_len, cut_len1)
    
    file_name_new = file_name[:cut_len1] + '_' + file_name[cut_len:cut_len1] + ext
    os.rename(file_name, file_name_new)
    
    return file_name_new

# %%
os.chdir("C:\\Users\\Suryansh Grover\\Downloads\\Assignments (iNeuron) - Copy")

# %%
for i in os.listdir():
    if '.docx' in i:
        if '(' and ')' in i:
            print("Original: ", i, '\n')
            renamed = rename(i)
            print("After renaming: ", renamed, '\n')
